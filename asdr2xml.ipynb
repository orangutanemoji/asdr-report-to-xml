# %%
#set input filepath in relation to this notebook
asdr_filename = 'DVO/ASDR.csv'

# %%
# This code block installs all the necessary libraries
# Only needs to be run once, set to False after initial run
FIRST_RUN = False
if FIRST_RUN:
    # !pip install pandas
    # !pip install numpy
    # !pip install lxml
    # !pip install xmlschema
    # !pip install dict2xml

# %%
import pandas as pd
import numpy as np
from lxml import etree as et
import xmlschema
import xml.etree.ElementTree as ET
from dict2xml import dict2xml
from xml.dom import minidom

# %%
output_filename = str(asdr_filename.split(".")[0]) + ".xml"

# Loop the data lines
with open(asdr_filename, 'r') as temp_f:
    # get No of columns in each line
    col_count = [ len(l.split(",")) for l in temp_f.readlines() ]

# Generate column names  (names will be 0, 1, 2, ..., maximum columns - 1)
column_names = [i for i in range(0, max(col_count))]

# Read csv
asdr_df = pd.read_csv(asdr_filename, header=None, delimiter=",", names=column_names)

# input CSV to excel
generate_excel = False
if generate_excel:
    asdr_df.to_excel(str((asdr_filename.split('.')[0] + ".xlsx")),header=False,index=False)

# %%
# create systems as nested dictionaries
# this can take a minute to run, needs to be optimized
systems = []
for row in range(len(asdr_df.index)):
    if asdr_df.iloc[row][0] == 'TEC System Name:' or asdr_df.iloc[row][0] == 'Zone System Name:':
        if row > 3:
            systems.append(system_info)
        system_info = {}
        system_info['NAME'] = asdr_df.iloc[row][1].replace('.','_')
    elif not pd.isna(asdr_df.iloc[row][1]):
        
        system_info[str(asdr_df.iloc[row][1]).split(":")[1]] = dict(zip(['VALUE','UNIT','STATUS'], asdr_df.iloc[row][4:7]))

systems.append(system_info)       

systems
# Out:
# [{'NAME': 'AY_VAV1-10',
#   'ADDRESS': {'VALUE': '24', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2523.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '71.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OVRD'},
#   'HEAT.COOL': {'VALUE': 'COOL', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '75.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'DAY HTG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT HTG STPT': {'VALUE': '65.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     OVRD'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '61.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW START': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW END': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'REHEAT START': {'VALUE': '24.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'REHEAT END': {'VALUE': '74.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OPER'},
#   'CLG FLOW MIN': {'VALUE': '92.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '1300.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MAX': {'VALUE': '1000.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '92.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.57', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '31.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '31.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'VLV COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'VLV POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '130.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '7.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG P GAIN': {'VALUE': '10.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '6.75', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '92.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '1300.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '71.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH LIMIT': {'VALUE': '5.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH TIME': {'VALUE': '10.0', 'UNIT': 'MIN', 'STATUS': ' -N-     NONE'},
#   'SWITCH DBAND': {'VALUE': '1.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '75.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '7.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.775', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'AY_VAV1-6',
#   'ADDRESS': {'VALUE': '20', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2520.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '71.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '65.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '74.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     OVRD'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '60.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '916.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '56.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.48', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '17.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '17.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '7.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '6.5', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '60.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '916.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '71.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '73.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '6.5', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.55', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'AY_VAV1-7',
#   'ADDRESS': {'VALUE': '21', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2520.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '70.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '55.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     OVRD'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '124.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '640.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '124.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.58', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '29.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '30.4', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '7.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '19.25', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '124.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '640.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '70.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OPER'},
#   'FLOW STPT': {'VALUE': '19.25', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.55', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'AY_VAV1-8',
#   'ADDRESS': {'VALUE': '22', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2520.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '71.5', 'UNIT': 'DEG F', 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '71.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '68.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '68.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     OVRD'},
#   'STPT DIAL': {'VALUE': 'YES', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '1020.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '1020.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.54', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '86.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '87.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '7.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '1020.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '71.5', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '68.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.55', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'AY_VAV1-9',
#   'ADDRESS': {'VALUE': '23', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2523.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '71.5', 'UNIT': 'DEG F', 'STATUS': ' -N-     OVRD'},
#   'HEAT.COOL': {'VALUE': 'COOL', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'DAY HTG STPT': {'VALUE': '72.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT HTG STPT': {'VALUE': '65.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '57.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     OVRD'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '62.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW START': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW END': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'REHEAT START': {'VALUE': '24.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'REHEAT END': {'VALUE': '74.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OPER'},
#   'CLG FLOW MIN': {'VALUE': '400.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '2000.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MIN': {'VALUE': '876.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MAX': {'VALUE': '1400.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '440.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.63', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '41.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '42.4', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'VLV COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'VLV POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '130.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '7.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG P GAIN': {'VALUE': '10.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '21.5', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '400.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '2000.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '71.5', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH LIMIT': {'VALUE': '5.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH TIME': {'VALUE': '10.0', 'UNIT': 'MIN', 'STATUS': ' -N-     NONE'},
#   'SWITCH DBAND': {'VALUE': '1.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '73.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '20.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '1.4', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_UNKNOWN',
#   'ADDRESS': {'VALUE': '1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2523.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '70.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'HEAT.COOL': {'VALUE': 'HEAT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY CLG STPT': {'VALUE': '75.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'DAY HTG STPT': {'VALUE': '69.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT HTG STPT': {'VALUE': '65.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '65.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '68.5', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW START': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW END': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '0.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'REHEAT START': {'VALUE': '24.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'REHEAT END': {'VALUE': '74.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OPER'},
#   'CLG FLOW MIN': {'VALUE': '76.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '372.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MIN': {'VALUE': '24.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'HTG FLOW MAX': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '24.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.86', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '90.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'VLV COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'VLV POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '150.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '5.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG P GAIN': {'VALUE': '10.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '24.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '24.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '70.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH LIMIT': {'VALUE': '5.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH TIME': {'VALUE': '10.0', 'UNIT': 'MIN', 'STATUS': ' -N-     NONE'},
#   'SWITCH DBAND': {'VALUE': '1.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '69.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '24.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.35', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_VAV1C10',
#   'ADDRESS': {'VALUE': '5', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2500.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '72.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'DAY CLG STPT': {'VALUE': '74.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '74.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '2.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '40.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '40.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '44.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.67', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '6.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '6.4', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'MTR2 COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '130.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '110.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '40.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '40.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '72.25', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR STATUS': {'VALUE': 'CAL', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL MODULE': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.35', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_VAV1C12',
#   'ADDRESS': {'VALUE': '7', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2500.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '71.75', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'DAY CLG STPT': {'VALUE': '74.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '95.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '2.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '1376.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '356.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.58', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '25.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '26.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'MTR2 COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '130.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '25.75', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '1376.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '71.75', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '20.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR STATUS': {'VALUE': 'CAL', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL MODULE': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OPER'},
#   'FLOW STPT': {'VALUE': '25.75', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.55', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_VAV1C7',
#   'ADDRESS': {'VALUE': '2', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2500.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OPER'},
#   'DAY CLG STPT': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '63.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '2.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '152.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '152.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '156.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.7', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '22.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '22.4', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'MTR2 COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '130.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '152.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '152.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OPER'},
#   'CLG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR STATUS': {'VALUE': 'CAL', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL MODULE': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '75.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     OPER'},
#   'FLOW STPT': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '0.35', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_VAV1R11',
#   'ADDRESS': {'VALUE': '6', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2523.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CHK STATUS': {'VALUE': ' -1.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'ROOM TEMP': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'HEAT.COOL': {'VALUE': 'COOL', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'DAY CLG STPT': {'VALUE': '72.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'DAY HTG STPT': {'VALUE': '70.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT CLG STPT': {'VALUE': '82.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'NGT HTG STPT': {'VALUE': '65.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'CHK OUT': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'RM STPT MIN': {'VALUE': '55.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT MAX': {'VALUE': '90.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'RM STPT DIAL': {'VALUE': '73.0',
#    'UNIT': 'DEG F',
#    'STATUS': ' -N-     NONE'},
#   'STPT DIAL': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 3': {'VALUE': '60.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW START': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW END': {'VALUE': '100.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'WALL SWITCH': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI OVRD SW': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OVRD TIME': {'VALUE': '2.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'NGT OVRD': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'REHEAT START': {'VALUE': '24.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'REHEAT END': {'VALUE': '74.8', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DI 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DI 3': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DAY.NGT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     OVRD'},
#   'CLG FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CLG FLOW MAX': {'VALUE': '2160.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MIN': {'VALUE': '252.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'HTG FLOW MAX': {'VALUE': '1080.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'AIR VOLUME': {'VALUE': '616.0', 'UNIT': ' CFM', 'STATUS': ' -N-     NONE'},
#   'FLOW COEFF': {'VALUE': '0.66', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'AI 4': {'VALUE': '74.0', 'UNIT': 'DEG F', 'STATUS': ' *F*     NONE'},
#   'DO 1': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 2': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 3': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO 4': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DMPR COMD': {'VALUE': '17.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'DMPR POS': {'VALUE': '17.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR1 TIMING': {'VALUE': '95.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'VLV COMD': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'VLV POS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'MTR2 TIMING': {'VALUE': '150.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'DMPR ROT ANG': {'VALUE': '90.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MTR SETUP': {'VALUE': '13.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DO DIR. REV': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG P GAIN': {'VALUE': '20.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CLG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG P GAIN': {'VALUE': '10.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'HTG BIAS': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW P GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW I GAIN': {'VALUE': '0.01', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW D GAIN': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'FLOW BIAS': {'VALUE': '50.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'FLOW': {'VALUE': '28.5', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CTL FLOW MIN': {'VALUE': '100.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL FLOW MAX': {'VALUE': '2160.0',
#    'UNIT': ' CFM',
#    'STATUS': ' -N-     NONE'},
#   'CTL TEMP': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CLG LOOPOUT': {'VALUE': '25.6', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'HTG LOOPOUT': {'VALUE': '0.0', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH LIMIT': {'VALUE': '5.2', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'SWITCH TIME': {'VALUE': '10.0', 'UNIT': 'MIN', 'STATUS': ' -N-     NONE'},
#   'SWITCH DBAND': {'VALUE': '1.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'CTL STPT': {'VALUE': '72.0', 'UNIT': 'DEG F', 'STATUS': ' -N-     NONE'},
#   'FLOW STPT': {'VALUE': '29.25', 'UNIT': 'PCT', 'STATUS': ' -N-     NONE'},
#   'CAL AIR': {'VALUE': 'NO', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL SETUP': {'VALUE': '4.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'CAL TIMER': {'VALUE': '12.0', 'UNIT': 'HRS', 'STATUS': ' -N-     NONE'},
#   'DUCT AREA': {'VALUE': '1.075', 'UNIT': 'SQ. FT', 'STATUS': ' -N-     NONE'},
#   'LOOP TIME': {'VALUE': '5.0', 'UNIT': 'SEC', 'STATUS': ' -N-     NONE'},
#   'ERROR STATUS': {'VALUE': '0.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'DHCD_VAV1R13',
#   'ADDRESS': {'VALUE': '8', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'APPLICATION': {'VALUE': '2523.0', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
# ...
#   'EFF HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'STRT MODE': {'VALUE': 'NO_STRT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX START IN': {'VALUE': '600.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX OCC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STRT': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STRT': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'STOP MODE': {'VALUE': 'NO_STOP', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX STOP IN': {'VALUE': '1440.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX VAC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STOP': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STOP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DISABLED': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DEFAULT MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'NEOB_LTG_TENANT_STATEof CA_HCD',
#   'ZN TEMP': {'VALUE': '32.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'OA TEMP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DESIRED OPER': {'VALUE': 'BOTH', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC HTG STPT': {'VALUE': '68.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OCC CLG STPT': {'VALUE': '78.8',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'MODE INPUT': {'VALUE': 'OCC', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MODE': {'VALUE': 'OCC', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX MODE': {'VALUE': 'OCC', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX OCC TIME': {'VALUE': '88200.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'NX VAC TIME': {'VALUE': '87690.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'PHASE': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'VAC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ACT HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'ACT CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'STRT MODE': {'VALUE': 'NO_STRT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX START IN': {'VALUE': '600.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX OCC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STRT': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STRT': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'STOP MODE': {'VALUE': 'NO_STOP', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX STOP IN': {'VALUE': '1440.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX VAC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STOP': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STOP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DISABLED': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DEFAULT MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'NEOB_WSHP_SCHEDULE',
#   'ZN TEMP': {'VALUE': '32.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'OA TEMP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DESIRED OPER': {'VALUE': 'BOTH', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC HTG STPT': {'VALUE': '68.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OCC CLG STPT': {'VALUE': '78.8',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'MODE INPUT': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MODE': {'VALUE': 'DAY', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX OCC TIME': {'VALUE': '91686.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'NX VAC TIME': {'VALUE': '91686.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'PHASE': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'VAC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ACT HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'ACT CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'STRT MODE': {'VALUE': 'NO_STRT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX START IN': {'VALUE': '600.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX OCC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STRT': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STRT': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'STOP MODE': {'VALUE': 'NO_STOP', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX STOP IN': {'VALUE': '1440.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX VAC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STOP': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STOP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DISABLED': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DEFAULT MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'OSHPD_8_VAV_ZONES',
#   'ZN TEMP': {'VALUE': '32.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'OA TEMP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DESIRED OPER': {'VALUE': 'BOTH', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC HTG STPT': {'VALUE': '68.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OCC CLG STPT': {'VALUE': '78.8',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'MODE INPUT': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MODE': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX MODE': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX OCC TIME': {'VALUE': '88080.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'NX VAC TIME': {'VALUE': '87659.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'PHASE': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'VAC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ACT HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'ACT CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'STRT MODE': {'VALUE': 'NO_STRT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX START IN': {'VALUE': '600.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX OCC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STRT': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STRT': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'STOP MODE': {'VALUE': 'NO_STOP', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX STOP IN': {'VALUE': '1440.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX VAC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STOP': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STOP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DISABLED': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DEFAULT MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'}},
#  {'NAME': 'OSHPD_9_VAV_ZONES',
#   'ZN TEMP': {'VALUE': '32.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'OA TEMP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DESIRED OPER': {'VALUE': 'BOTH', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC HTG STPT': {'VALUE': '68.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OCC CLG STPT': {'VALUE': '78.8',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'VAC CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'MODE INPUT': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'MODE': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX MODE': {'VALUE': 'OCC1', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'NX OCC TIME': {'VALUE': '88080.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'NX VAC TIME': {'VALUE': '87659.0',
#    'UNIT': 'min',
#    'STATUS': ' -N-     NONE'},
#   'PHASE': {'VALUE': 'OFF', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'OCC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'VAC TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ACT HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'ACT CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF HTG STPT': {'VALUE': '53.6',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'EFF CLG STPT': {'VALUE': '86.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'STRT MODE': {'VALUE': 'NO_STRT', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX START IN': {'VALUE': '600.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX OCC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STRT TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STRT': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STRT': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STRT': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'STOP MODE': {'VALUE': 'NO_STOP', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'TG TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'NX STOP IN': {'VALUE': '1440.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX VAC IN': {'VALUE': '4380.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP DRTN': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'NX STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'STOP TIME': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'ZN TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'OA TEMP STOP': {'VALUE': '32.0',
#    'UNIT': 'deg F',
#    'STATUS': ' -N-     NONE'},
#   'TIME DV STOP': {'VALUE': '0.0', 'UNIT': 'min', 'STATUS': ' -N-     NONE'},
#   'TEMP DV STOP': {'VALUE': '0.0', 'UNIT': 'deg F', 'STATUS': ' -N-     NONE'},
#   'DISABLED': {'VALUE': 'ON', 'UNIT': nan, 'STATUS': ' -N-     NONE'},
#   'DEFAULT MODE': {'VALUE': 'NIGHT', 'UNIT': nan, 'STATUS': ' -N-     NONE'}}]

# %%
# find unique entries
output_df = pd.read_xml("DVO\Bacnet-Export.xml")
output_df
for column in output_df.columns:
    if len(output_df[column].unique()) < 100:
        print(column,output_df[column].unique())
    else:
        print(column)
# Out:
# Inst
# Name
# Desc
# NC [1]
# Type ['Analog-Value' 'Binary-Value' 'Analog-Input' 'Notification-Class']
# Enabled [ True]
# Alarm ['true' None]
# OM ['GMS_APOGEE_TEC_APPL_2500_EN' 'GMS_APOGEE_TEC_APPL_2523_EN'
#  'GMS_APOGEE_TEC_APPL_2520_EN' 'GMS_APOGEE_TEC_APPL_2021_EN'
#  'GMS_APOGEE_TEC_APPL_2023_EN' 'GMS_APOGEE_P2_EO_BA_LDO_V'
#  'GMS_APOGEE_P2_EO_BA_LAO_V' 'GMS_APOGEE_P2_EO_BA_LAI_1'
#  'GMS_APOGEE_P2_EO_BA_LDI_V' None]
# MappedDp
# MappedDpe ['ROOM_TEMP' 'DMPR_COMD' 'AIR_VOLUME' 'CTL_STPT' 'AI_3' 'VLV_COMD'
#  'CTL_TEMP' 'SUPPLY_TEMP' 'MTR2_COMD' 'DMPR_POS' 'AUX_TEMP' 'VLV1_COMD'
#  '_Property_NoMapping' None]
# ZeroBase ['false' None]
# TONpri [ nan 120.]
# TFpri [ nan 120.]
# TNpri [ nan 120.]

# %%
# make Names
mappings =  ['ROOM_TEMP', 'DMPR_COMD', 'AIR_VOLUME', 'CTL_STPT', 'AI_3',
             'VLV_COMD', 'CTL_TEMP_IGNORE', 'SUPPLY_TEMP', 'MTR2_COMD', 'DMPR_POS_IGNORE',
             'AUX_TEMP', 'VLV1_COMD']
mapping_codes = ['004','048','035','092','015','052','078','015','052','049','015','052']

mapping_spaces = []
combined_mappings = []

for i in range(len(mappings)):
    mapping_spaces.append(mappings[i].replace("_"," "))
    combined_mappings.append('(' + mapping_codes[i] + ') ' + mapping_spaces[i])
combined_mappings
# Out:
# ['(004) ROOM TEMP',
#  '(048) DMPR COMD',
#  '(035) AIR VOLUME',
#  '(092) CTL STPT',
#  '(015) AI 3',
#  '(052) VLV COMD',
#  '(078) CTL TEMP IGNORE',
#  '(015) SUPPLY TEMP',
#  '(052) MTR2 COMD',
#  '(049) DMPR POS IGNORE',
#  '(015) AUX TEMP',
#  '(052) VLV1 COMD']

# %%
# build default system info
output_columns = ['Inst', 'Name', 'Desc', 'NC', 'Type', 'Enabled', 'Alarm', 'OM', 'MappedDp', 'MappedDpe','ZeroBase']
default_values = [None,None,None,'1',"Analog-Value",'true','true',None,None,None,'false']
inst_counter = 1

dev_attrib = dict(zip(["Inst","Name","Desc","Enabled","ReadOnly"],
                      ["1","VirtualBACnetDevice","Virtual BACnet Device","true","true"]))


output_df = pd.DataFrame(columns=output_columns)
root = ET.Element('DEV',dev_attrib)

# %%
# build element tree
for system in systems:
    for key in list(system.keys()):
        
        if key in mapping_spaces:
            current_row = default_values

            # Inst
            current_row[0] = str(inst_counter)
            inst_counter += 1

            # Name
            current_row[1] = str(system['NAME']) + " - " + combined_mappings[mapping_spaces.index(key)]

            # Desc
            current_row[2] = system['NAME']
            
            # OM
            current_row[7] = ("GMS_APOGEE_TEC_APPL_" + str(int(float(system['APPLICATION']['VALUE']))) + "_EN")
            
            # MappedDp
            current_row[8] = ("GMS_AP2_" + ((system['NAME']).replace("_","?")))

            # MappedDpe
            current_row[9] = mappings[mapping_spaces.index(key)]
            
            output_df.loc[len(output_df.index)] = (current_row) 
            
            current_tags = dict(zip(output_columns,current_row))
            ET.SubElement(root, 'OBJ', attrib=current_tags)

# %%
# output to xml file
xml_str = minidom.parseString(ET.tostring(root,xml_declaration=None)).toprettyxml(indent="   ")
xml_str = xml_str.split("<?xml version=\"1.0\" ?>")[1][1:]
with open(output_filename, "w") as f:
    f.write(xml_str)
